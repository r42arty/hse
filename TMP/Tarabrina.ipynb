# %% [markdown]
# <a href="https://colab.research.google.com/github/r42arty/hse/blob/main/TMP/Tarabrina.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## <center> Практическое домашнее задание 1 </center>
#
# *`credits to ML course by E. Sokolov`*
#
# ### Общая информация
#
# Дата выдачи: 01.02.2025
#
# Первый дедлайн: 07:59MSK 20.02.2025
#
# Второй дедлайн: 07:59MSK 24.02.2025

# %% [markdown]
# ### О задании
#
# Задание состоит из двух разделов, посвященных работе с табличными данными с помощью библиотеки `pandas` и визуализации с помощью `matplotlib`. В первом разделе вам предстоит выполнить базовые задания с помощью вышеуказанных библиотек, а во втором распределить студентов по курсам. Баллы даются за выполнение отдельных пунктов. Задачи в рамках одного раздела рекомендуется решать в том порядке, в котором они даны в задании.
#
# Задание направлено на освоение jupyter notebook (будет использоваться в дальнейших заданиях), библиотек pandas и matplotlib.
#
# ### Оценивание и штрафы
# Каждая из задач имеет определенную «стоимость» (указана в скобках около задачи).
#
# **Штраф за каждый день просрочки мягкого дедлайна**: 0.5 баллов. После жесткого дедлайна работы не принимаются.
#
# Задание выполняется самостоятельно. «Похожие» решения считаются плагиатом и все задействованные студенты (в том числе те, у кого списали) не могут получить за него больше 0 баллов. Если вы нашли решение какого-то из заданий (или его часть) в открытом источнике, необходимо указать ссылку на этот источник.
#
# ### Формат сдачи
# Задания сдаются через гугл-форму https://forms.gle/pT6CtSPNRXoqd64d6. Сам ноутбук называйте в формате homework-practice-01-pandas-Username.ipynb, где Username — ваша фамилия.

# %% [markdown]
# ## 0. Введение

# %% [markdown]
# Сейчас мы находимся в jupyter-ноутбуке (или ipython-ноутбуке). Это удобная среда для написания кода, проведения экспериментов, изучения данных, построения визуализаций и других нужд, не связанных с написанием production-кода.
#
# Ноутбук состоит из ячеек, каждая из которых может быть либо ячейкой с кодом, либо ячейкой с текстом размеченным и неразмеченным. Текст поддерживает markdown-разметку и формулы в Latex.
#
# Для работы с содержимым ячейки используется *режим редактирования* (*Edit mode*, включается нажатием клавиши **Enter** после выбора ячейки), а для навигации между ячейками искользуется *командный режим* (*Command mode*, включается нажатием клавиши **Esc**). Тип ячейки можно задать в командном режиме либо с помощью горячих клавиш (**y** to code, **m** to markdown, **r** to edit raw text), либо в меню *Cell -> Cell type*.
#
# После заполнения ячейки нужно нажать *Shift + Enter*, эта команда обработает содержимое ячейки: проинтерпретирует код или сверстает размеченный текст.

# %%
# ячейка с кодом, при выполнении которой появится output
2 + 2
# Out:
# 4

# %% [markdown]
# Ячейка с неразмеченным текстом.

# %% [markdown]
# Попробуйте создать свои ячейки, написать какой-нибудь код и текст какой-нибудь формулой.

# %%
# your code
class Tiger:
    def __init__(self, name, age, species='Амурский тигр'):
        self.name = name
        self.age = age
        self.species = species

    def sound(self):
        return f'{self.name} грозно рычит.'

    def info(self):
        return f'Кличка: {self.name}\nВозраст: {self.age} лет\nВид: {self.species}'

tiger = Tiger('Пушок', 5)
print(tiger.info())
print(tiger.sound())
# Out:
# Кличка: Пушок
# Возраст: 5 лет
# Вид: Амурский тигр
# Пушок грозно рычит.

# %% [markdown]
# $$
# MSE = \frac{1}{n} \sum_{i=1}^{n} (y_{_i} - y_{\text{pred}_i})^2
# $$

# %% [markdown]
# [Здесь](https://athena.brynmawr.edu/jupyter/hub/dblank/public/Jupyter%20Notebook%20Users%20Manual.ipynb) находится <s>не</s>большая заметка о используемом языке разметки Markdown. Он позволяет:
#
# 0. Составлять упорядоченные списки
# 1. Выделять *текст* <s>при</s> **необходимости**
# 2. Добавлять [ссылки](http://imgs.xkcd.com/comics/the_universal_label.png)
#
#
# * Составлять неупорядоченные списки
#
# Делать вставки с помощью LaTex:
#
# $
# \left\{
# \begin{array}{ll}
# x = 16 \sin^3 (t) \\
# y = 13 \cos (t) - 5 \cos (2t) - 2 \cos (3t) - \cos (4t) \\
# t \in [0, 2 \pi]
# \end{array}
# \right.$

# %% [markdown]
# А ещё можно вставлять картинки, или гифки, или что захотите:
#
# <img src="https://media1.tenor.com/images/9b8fbe9214504bcf6c60fe4e4f7e114e/tenor.gif?itemid=5416416" style="width: 400px">

# %% [markdown]
# ### Google Colab

# %% [markdown]
# Что за колаб?
#
# **Google Colab (Colaboratory)** это **Jupyter Notebook + Cloud + Google Drive.**
#
# Компания Google предоставляет возможность бесплатно запускать ноутбуки (предварительно загрузив их на свой гугл-диск) прямо в облаке. При этом вам не требуется установка никаких пакетов на свою машину, а работать можно прямиком из браузера. Вот ссылка:

# %% [markdown]
# https://colab.research.google.com

# %% [markdown]
# При использовании вы увидете много сходств с jupyter ноутбуком. Одним из преимуществ является доступность GPU, соответствующую опцию можно активировать в настройках сервиса. При желании вы сможете найти в интернете много туториалов по использованию или разобраться самостоятельно =)

# %% [markdown]
# ## 1. Табличные данные и Pandas

# %% [markdown]
# Pandas — удобная библиотека для работы с табличными данными в Python, если данных не слишком много и они помещаются в оперативную память вашего компьютера. Несмотря на неэффективность реализации и некоторые проблемы, библиотека стала стандартом в анализе данных.
#
# Основной объект в pandas — это DataFrame, представляющий собой таблицу с именованными колонками различных типов, индексом (может быть многоуровневым). DataFrame можно создавать, считывая таблицу из файла или задавая вручную из других объектов.
#
# В этой части потребуется выполнить несколько небольших заданий. Можно пойти двумя путями: сначала изучить материалы, а потом приступить к заданиям, или же разбираться "по ходу". Выбирайте сами.
#
# Материалы:
# 1. [Pandas за 10 минут из официального руководства](http://pandas.pydata.org/pandas-docs/stable/10min.html)
# 2. [Документация](http://pandas.pydata.org/pandas-docs/stable/index.html) (стоит обращаться, если не понятно, как вызывать конкретный метод)
# 3. [Примеры использования функционала](http://nbviewer.jupyter.org/github/justmarkham/pandas-videos/blob/master/pandas.ipynb)
#
# Многие из заданий можно выполнить несколькими способами. Не существуют единственно верного, но попробуйте максимально задействовать арсенал pandas и ориентируйтесь на простоту и понятность вашего кода. Мы не будем подсказывать, что нужно использовать для решения конкретной задачи, попробуйте находить необходимый функционал сами (название метода чаще всего очевидно). В помощь вам документация, поиск и stackoverflow.

# %%
# %pylab inline
import pandas as pd
import numpy as np
# Out:
# Populating the interactive namespace from numpy and matplotlib

# %% [markdown]
# Скачаем подготовленные данные командой ниже:

# %%
# !wget  -O 'end_seminar.xlsx' -q 'https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0'

# %% [markdown]
# **В первой части задания (до раздела "Распределение студентов по курсам") использование циклов запрещается и повлечет за собой снижение оценки. Использование <code>vectorize</code> и  <code>apply</code>, <code>apply_along_axis</code> крайне нежелательно.**

# %% [markdown]
# Для каждой задачи из этого раздела вы должны написать код для получения ответа, а также дать текстовый ответ, если он предполагается.
#
# На некоторые вопросы вы можете получить путём пристального взгляда на таблицу, но это не будет засчитываться. Вы в любом случае должны получить ответ с помощью кода.

# %% [markdown]
# #### 1. [0 баллов] Откройте файл с таблицей (не забудьте про её формат). Выведите последние 10 строк.

# %%
# your code
df = pd.read_excel('end_seminar.xlsx')
df.tail(10)
# Out:
#                   timestamp                                id  rating  \
# 351 2020-05-18 23:58:33.903  8fe79f84f36e3a5d2d6745621321302c    1016
# 352 2020-05-18 23:59:20.831  f93afd8e92c336b471aa3bbbc579aefe    1298
# 353 2020-05-18 23:59:28.998  9963fc00d9405a35b894cc04a7e19855    1135
# 354 2020-05-19 08:55:39.509  98c5a2548d93f26bd4195466e93178b3    1035
# 355 2020-05-19 18:58:06.283  ba298cbd9be59b84bab33325e956f27e    1155
# 356 2020-05-19 19:04:17.873  c5870b37ee3f672e4259dfb2fc02ed8f    1029
# 357 2020-05-19 20:19:25.815  f44aea1095f9f5b8e2f5f0ed2b17891b    1060
# 358 2020-05-20 11:54:38.318  d7118b44c7e8fdbbaaca226d2da6fef1    1111
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 360 2020-05-23 21:16:40.916  f2d210ace25a841e1e58036b257d5d47    1195
#
#      18_group  is_mi                                           fall_1  \
# 351       NaN    NaN                 Безопасность компьютерных систем
# ...

# %% [markdown]
# #### 2. [1 балл] Есть ли в данных пропуски? В каких колонках? Сколько их в каждой из этих колонок?

# %%
# your code
null_data = df.isna().sum()
null_data = null_data[null_data != 0]
print(f'Количество пропусков в колонках:\n{null_data}')
# Out:
# Количество пропусков в колонках:
# 18_group         138
# is_mi            343
# is_first_time      2
# 17_group         223
# blended          223
# is_ml_student    304
# dtype: int64

# %% [markdown]
# Заполните пропуски пустой строкой для строковых колонок и нулём для числовых (постарайтесь избежать перечисления названий всех столбцов).

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 361 entries, 0 to 360
# Data columns (total 16 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   timestamp      361 non-null    datetime64[ns]
#  1   id             361 non-null    object
#  2   rating         361 non-null    int64
#  3   18_group       223 non-null    float64
#  4   is_mi          18 non-null     float64
#  5   fall_1         361 non-null    object
#  6   fall_2         361 non-null    object
#  7   fall_3         361 non-null    object
#  8   spring_1       361 non-null    object
#  9   spring_2       361 non-null    object
#  10  spring_3       361 non-null    object
#  11  is_first_time  359 non-null    object
#  12  percentile     361 non-null    float64
#  13  17_group       138 non-null    float64
#  14  blended        138 non-null    object
#  15  is_ml_student  57 non-null     float64
# dtypes: datetime64[ns](1), float64(5), int64(1), object(9)
# ...

# %%
# your code
df = df.fillna({column: '' if df[column].dtype == 'object' else 0 for column in df.columns})
df
# Out:
#                   timestamp                                id  rating  \
# 0   2020-05-15 01:12:50.543  93ff79a51cd602f1dd3028ba2c129503     698
# 1   2020-05-15 02:46:48.066  26b01b1c4cd5656bab18d24c548834fb     647
# 2   2020-05-15 03:12:41.480  30f3653fc176d54e89ac3179c455c6dd     624
# 3   2020-05-15 04:43:08.994  1528f0eaa027580820ccf0d92a53ad68     579
# 4   2020-05-15 07:47:17.197  496ea4f0d4abe264b1bb1b80eb3830c5     572
# ..                      ...                               ...     ...
# 356 2020-05-19 19:04:17.873  c5870b37ee3f672e4259dfb2fc02ed8f    1029
# 357 2020-05-19 20:19:25.815  f44aea1095f9f5b8e2f5f0ed2b17891b    1060
# 358 2020-05-20 11:54:38.318  d7118b44c7e8fdbbaaca226d2da6fef1    1111
# 359 2020-05-23 21:16:40.916  79d14db48e4737af731960ae212d5134     966
# 360 2020-05-23 21:16:40.916  f2d210ace25a841e1e58036b257d5d47    1195
#
#      18_group  is_mi                                           fall_1  \
# ...

# %% [markdown]
# #### 3. [1 балл] Посмотрите повнимательнее на колонку 'is_first_time'.
#
# Есть ли в ней ответы "Нет"? Сколько их?
#
# Если вы найдете повторные обращения студентов, оставьте только самую позднюю версию. В дальнейших заданиях используйте версию данных без повторов.
#
# <i>Обращения со значением "Нет" в 'is_first_time' могут быть как повторными, так и первичными, поскольку поле заполняли сами студенты.</i>

# %%
# your code
answer_no_before = (df['is_first_time'] == 'Нет').sum()
print(f'Количество ответов "Нет" до удаления повторных обращений: {answer_no_before}')

# Проверим наличие повторных обращений по id обращения:
duplicate_counts = (df['id'].value_counts() > 1).sum()
print(f'Количество повторных обращений: {duplicate_counts}')

#print(f'Тип данных в столбце timestamp: {df["timestamp"].dtype}') #проверили тип данных, чтобы понимать, нужно ли его менять для сортировки

df_last = df.sort_values(by='timestamp').drop_duplicates(subset='id', keep='last').reset_index(drop=True) #записала в новый датафрейм, чтобы не менять исходный дф и проверять себя при выполнении дальнейших задач

answer_no_after = (df_last['is_first_time'] == 'Нет').sum()
print(f'Количество ответов "Нет" после удаления повторных обращений: {answer_no_after}')
# Out:
# Количество ответов "Нет" до удаления повторных обращений: 51
# Количество повторных обращений: 14
# Количество ответов "Нет" после удаления повторных обращений: 51

# %% [markdown]
# Количество ответов "нет" не изменилось. Проверим себя:

# %%
answer_yes_before = (df['is_first_time'] == 'Да').sum()
print(f'Количество ответов "Да" до удаления повторных обращений: {answer_yes_before}')

answer_yes_after = (df_last['is_first_time'] == 'Да').sum()
print(f'Количество ответов "Да" после удаления повторных обращений: {answer_yes_after}')

df.shape[0] - df_last.shape[0] #сравнили количество строк в датафреймах
# Out:
# Количество ответов "Да" до удаления повторных обращений: 308
# Количество ответов "Да" после удаления повторных обращений: 294
# 14

# %% [markdown]
# Видим, что повторные обращения были только с ответами "Да". Таким образом, мы убрали 14 строк с повторными обращениями, оставив последние.
#
# **P.S. Далее будем использовать новый датафрейм df_last, т.к. в задании написано "использовать версию данных без повторов" (при этом не указано, как эту версию сохранить: нужно изменить исходный датафрейм или сделать новый. Я предпочла сделать новый).**

# %% [markdown]
# #### 4. [1 балл] Ответьте на вопросы:
# 1. Сколько было заявок из групп 18-го года набора, а сколько из групп 17-го года?
# 2. Есть ли студенты с равными перцентилями (среди объединенных данных, ведь конкурс на каждый курс общий)?

# %%
# your code
#print(df_last[['18_group', '17_group']].dtypes) #cначала проверим тип данных в ячейках

count_by_group = lambda df_last, col: df_last[df_last[col] != 0].shape[0] #можно еще использовать lambda df_last, col, year: df_last[df_last[col].astype(str).str.startswith(year)].shape[0]

count_18_group = count_by_group(df_last, '18_group')
count_17_group = count_by_group(df_last, '17_group')

print(f'Количество заявок из групп 18-го года: {count_18_group}')
print(f'Количество заявок из групп 17-го года: {count_17_group}')

#Найдем повторяющиеся перцентили
duplicates_percentile = (
    df_last[df_last.duplicated(subset='percentile', keep=False)]
    .groupby('percentile')['id']
    .agg(list)
    .to_dict()
)

for percentile, id in duplicates_percentile.items():
    print(f'Перцентиль {percentile} есть у студентов с id: {", ".join(map(str, id))}')
# Out:
# Количество заявок из групп 18-го года: 213
# Количество заявок из групп 17-го года: 134
# Перцентиль 0.0 есть у студентов с id: 3a7326c9e355a67d3805824ca34c4bc5, 3e106aaef8b24dbb01319c73e14c2936

# %%
#Смущает, что всего два студента с одинаковыми перцентилями. Можем проверить себя на исходном датафрейме (с повторными обращениями):
duplicates_perc = (
    df[df.duplicated(subset='percentile', keep=False)]
    .groupby('percentile')['id']
    .agg(list)
    .to_dict()
)

for percentile, id in duplicates_perc.items():
    print(f'Перцентиль {percentile} есть у студентов с id: {", ".join(map(str, id))}')
# Out:
# Перцентиль 0.0 есть у студентов с id: 3e106aaef8b24dbb01319c73e14c2936, 3a7326c9e355a67d3805824ca34c4bc5
# Перцентиль 0.2040358744394619 есть у студентов с id: b121e4d7d62387cd5199cca464a34a6d, b121e4d7d62387cd5199cca464a34a6d
# Перцентиль 0.2934782608695652 есть у студентов с id: 9a66d84568b8017d98eb2e678b57296b, 9a66d84568b8017d98eb2e678b57296b
# Перцентиль 0.3385650224215246 есть у студентов с id: 9015b809a29fb65ce23d7addf16d770d, 9015b809a29fb65ce23d7addf16d770d
# Перцентиль 0.3699551569506726 есть у студентов с id: ffc58d371e2f52e1c7f45d49d3d629d0, ffc58d371e2f52e1c7f45d49d3d629d0
# Перцентиль 0.5134529147982063 есть у студентов с id: 5ee2ad618729a6dc3bdb7f2858826ef0, 5ee2ad618729a6dc3bdb7f2858826ef0
# Перцентиль 0.5269058295964126 есть у студентов с id: a65d50ef4fadfac64508a54e972d8623, a65d50ef4fadfac64508a54e972d8623
# Перцентиль 0.5471014492753623 есть у студентов с id: 906692ccd33f59058380aac1598c5480, 906692ccd33f59058380aac1598c5480
# ...

# %% [markdown]
# #### 5. [1 балл] Какие  blended-курсы для четверокурсников существуют? На какой blended-курс записалось наибольшее количество студентов? На каком из blended-курсов собрались студенты с самым высоким средним рейтингом (выведите этот курс и количество студентов на нем)?

# %%
# your code
courses = df_last['blended'].dropna().unique()
courses = [course for course in courses if course.strip()]
print(f'Для четверокурсников существуют курсы: {", ".join(courses)}')

course_counts = df_last['blended'].replace('', np.nan).dropna().value_counts()
print(f'Наибольшее количество студентов ({course_counts.iloc[0]}) записалось на blended-курс {course_counts.index[0]}')

#display(course_counts) #для проверки

course_ratings_mean = df_last.replace('', np.nan).dropna(subset=['blended']).groupby('blended').agg(
    rating_mean = ('rating', 'mean'),
    student_count = ('blended', 'count')
).reset_index()

#display(course_ratings_mean) #для проверки.

max_rating_index = course_ratings_mean['rating_mean'].idxmax()
max_rating_course = course_ratings_mean.loc[max_rating_index, 'blended']
max_rating_student_count = course_ratings_mean.loc[max_rating_index, 'student_count']

print(f'На blended-курс "{max_rating_course}" собралось {max_rating_student_count} студентов с самым высоким средним рейтингом.')
# Out:
# Для четверокурсников существуют курсы: DevOps, Введение в дифференциальную геометрию, Соревновательный анализ данных
# Наибольшее количество студентов (87) записалось на blended-курс DevOps
# На blended-курс "Введение в дифференциальную геометрию" собралось 15 студентов с самым высоким средним рейтингом.

# %% [markdown]
# #### 6. [1.5 балл] Выясните, есть ли студенты с абсолютно одинаковыми предпочтениями по всем курсам.
#
# Для этого сформируйте таблицу, где для каждого возможного набора курсов посчитано количество студентов, выбравших такой набор, и оставьте только строки где это количество больше 1.
#
# В данном случае набор курсов задается упорядоченным множеством ('fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended'). Элемент blended будет нулевым для 3-го курса.

# %%
# your code
list_of_courses = ['fall_1', 'fall_2', 'fall_3', 'spring_1', 'spring_2', 'spring_3', 'blended']
students_choise = df_last[list_of_courses].groupby(list_of_courses).size().reset_index(name='students_count') #если бы тип данных был другой, то нужно было бы еще добавить .astype(str)
same_choise = students_choise[students_choise['students_count'] > 1]
same_choise
# Out:
#                                               fall_1  \
# 0                        Statistical Learning Theory
# 60             Байесовские методы машинного обучения
# 62             Байесовские методы машинного обучения
# 72                  Безопасность компьютерных систем
# 84                  Безопасность компьютерных систем
# 102                 Безопасность компьютерных систем
# 105                 Безопасность компьютерных систем
# 113                 Безопасность компьютерных систем
# 137                 Безопасность компьютерных систем
# 155                 Безопасность компьютерных систем
# 184                Высокопроизводительные вычисления
# 201                Высокопроизводительные вычисления
# 244                    Моделирование временных рядов
# 292  Сбор и обработка данных с помощью краудсорсинга
# 313                                         Язык SQL
#
#                                               fall_2  \
# 0                  Анализ неструктурированных данных
# ...

# %% [markdown]
# #### 7. [0.5 балла] Найдите курсы по выбору, на которые записывались как студенты 18-го года набора, так и студенты 17-го года.

# %%
students_18_group = df_last[df_last['18_group'].astype(str).str.startswith('18')]
students_17_group = df_last[df_last['17_group'].astype(str).str.startswith('17')]

courses_18_group = set(students_18_group[list_of_courses].values.ravel()) - {None, '', np.nan}
courses_17_group = set(students_17_group[list_of_courses].values.ravel()) - {None, '', np.nan}

courses_17_18 = courses_18_group & courses_17_group

print(f"Курсы, на которые записывались как студенты 18-го года набора, и студенты 17-го года:\n{', '.join(courses_17_18)}")
# Out:
# Курсы, на которые записывались как студенты 18-го года набора, и студенты 17-го года:
# Численные методы, Высокопроизводительные вычисления, Statistical Learning Theory, Безопасность компьютерных систем, Моделирование временных рядов, Принятие решений в условиях риска и неопределённости, Сбор и обработка данных с помощью краудсорсинга

# %% [markdown]
# Методом исключения найдите курсы, которые предлагались только студентам 18-го года и только студентам 17-го года.

# %%
# your code
courses_18_only = courses_18_group - courses_17_group
courses_17_only = courses_17_group - courses_18_group

print(f"Курсы, которые предлагались только студентам 18-го года:\n{', '.join(courses_18_only)}")
print(f"Курсы, которые предлагались только студентам 17-го года:\n{', '.join(courses_17_only)}")
# Out:
# Курсы, которые предлагались только студентам 18-го года:
# Дополнительные главы прикладной статистики, Матричные вычисления, Промышленное программирование на языке Java, Теория баз данных, Системы баз данных, Анализ данных в бизнесе, Машинное обучение 2, Язык SQL, Дискретная оптимизация, Компьютерные сети
# Курсы, которые предлагались только студентам 17-го года:
# Байесовские методы машинного обучения, Генеративные модели в машинном обучении, Введение в дифференциальную геометрию, Методы сжатия и передачи медиаданных, DevOps, Анализ неструктурированных данных, Конфликты и кооперация, Обучение с подкреплением, Символьные вычисления, Компьютерное зрение, Проектирование и разработка высоконагруженных сервисов, Глубинное обучение в обработке звука, Соревновательный анализ данных

# %% [markdown]
# ### Визуализации и matplotlib

# %% [markdown]
# При работе с данными часто неудобно делать какие-то выводы, если смотреть на таблицу и числа в частности, поэтому важно уметь визуализировать данные. Здесь будут описаны ключевые правила оформления графиков для **всех** домашних заданий.
#
# У matplotlib, конечно же, есть [документация](https://matplotlib.org/users/index.html) с большим количеством [примеров](https://matplotlib.org/examples/), но для начала достаточно знать про несколько основных типов графиков:
# - plot — обычный поточечный график, которым можно изображать кривые или отдельные точки;
# - hist — гистограмма, показывающая распределение некоторой величины;
# - scatter — график, показывающий взаимосвязь двух величин;
# - bar — столбцовый график, показывающий взаимосвязь количественной величины от категориальной.
#
# В этом задании вы попробуете построить один из них. Не забывайте про базовые принципы построения приличных графиков:
# - оси должны быть подписаны, причём не слишком мелко;
# - у графика должно быть название;
# - если изображено несколько графиков, то необходима поясняющая легенда;
# - все линии на графиках должны быть чётко видны (нет похожих цветов или цветов, сливающихся с фоном);
# - если отображена величина, имеющая очевидный диапазон значений (например, проценты могут быть от 0 до 100), то желательно масштабировать ось на весь диапазон значений (исключением является случай, когда вам необходимо показать малое отличие, которое незаметно в таких масштабах);
# - сетка на графике помогает оценить значения в точках на глаз, это обычно полезно, поэтому лучше ее отрисовывать;
# - если распределение на гистограмме имеет тяжёлые хвосты, лучше использовать логарифмическую шкалу.
#
# Еще одна билиотека для визуализации: [seaborn](https://jakevdp.github.io/PythonDataScienceHandbook/04.14-visualization-with-seaborn.html) (обычно сокращается до sns). Это настройка над matplotlib, иногда удобнее и красивее делать визуализации через неё.
#
# **5 пунктов после которых ваши графики не будут прежними:**
# - для красивой картинки <code>%config InlineBackend.figure_format = 'retina'</code>
# - задаем размер (почти) всех графиков (можно выбрать другие значения) <code>plt.rcParams['figure.figsize'] = 8, 5</code>
# - размер шрифта подписей графиков <code>plt.rcParams['font.size'] = 12</code>
# - формат в котором сохраняется изображение <code>mpl.rcParams['savefig.format'] = 'pdf'</code>
# - sns – seaborn, добавляет решетку <code>sns.set_style('darkgrid')</code>
#
# Добавьте эти функции в ячейку ниже. Каждый график все равно придется настраивать отдельно, но указанные строчки позволят значительно упростить процесс.

# %%
# %matplotlib inline
import matplotlib.pyplot as plt
import seaborn as sns

# your code

# %% [markdown]
# #### 8. [0.5 балла] Постройте график средних рейтингов по дням получения ответов (bar plot).

# %%
df_last['date'] = df_last['timestamp'].dt.date
daily_mean_rating = df_last.groupby('date')['rating'].mean().reset_index()

plt.figure(figsize=(10, 6))
sns.barplot(x='date', y='rating', data=daily_mean_rating)
plt.xlabel('Дата')
plt.ylabel('Средний рейтинг')
plt.title('Средние рейтинги по дням получения ответов')
plt.xticks(rotation=45)
plt.show()

# %% [markdown]
# Сохраните график в формате pdf (так он останется векторизованным).

# %%
# your code
#нам нужно воспроизвести код заново, т.к plt.savefig() сохраняет пустой файл, если ввести эту команду после plt.show()
plt.figure(figsize=(10, 6))
sns.barplot(x='date', y='rating', data=daily_mean_rating)
plt.xlabel('Дата')
plt.ylabel('Средний рейтинг')
plt.title('Средние рейтинги по дням')
plt.xticks(rotation=45)

plt.savefig('daily_mean_rating.pdf', format='pdf', bbox_inches='tight')

plt.close() #чтобы график не отображался после этой ячейки

# %% [markdown]
# ### 2. Распределение студентов по курсам.

# %% [markdown]
# Теперь вам нужно распределить студентов по осенним курсам по выбору, учитывая их предпочтения.

# %% [markdown]
# Алгоритм распределения студентов по курсам:
# 1. По умолчанию на каждой дисциплине по выбору у 3 и 4 курсов может учиться 1 группа (до 30 студентов). Исключения описаны ниже. На blended-дисциплинах для четверокурсников количество мест не ограничено.
# 2. Проводится первая волна отбора. Для каждой дисциплины формируется список тех, кто указал её первым приоритетом (если студент должен выбрать два курса по выбору, то для него дисциплины, которые он указал первым и вторым приоритетом, рассматриваются как дисциплины первого приоритета). Если желающих больше, чем мест, то выбирается топ по перцентилю рейтинга.
# 3. На дисциплинах, где остались места после первой волны, формируются списки тех, кто выбрал их вторым приоритетом и еще не прошел на необходимое количество курсов. Места заполняются лучшими по перцентилю рейтинга студентами. После этого проводится такая же процедура для дисциплин третьего приоритета.
# 4. Если студент не попал на необходимое количество курсов по итогам трёх волн, с ним связывается учебный офис и решает вопрос в индивидуальном порядке.

# %% [markdown]
# Обращаем ваше внимание на следующие детали:
# - Конкурс на каждый курс общий для 3-го и 4-го курса
#
# - По умолчанию студент выбирает один осенний и один весенний курс по выбору, а также четверокурсники выбирают один blended-курс. Студенты групп 17-го года специализаций МОП и ТИ выбирают по 2 осенних и 2 весенних курса по выбору, также студенты групп 18' специализации МИ выбирают 2 осенних курса. <i>Для студентов, которые выбирают 2 курса (например, осенних) первый приоритет — <code>fall_1</code> и <code>fall_2</code>, второй приоритет — <code>fall_3</code>. Такие студенты участвуют только в двух волнах отбора</i>.
#
# - Студенты специализации МОП не могут выбрать весенним курсом по выбору Машинное обучение 2. **Если студент специализации МОП выбрал Машинное обучение 2, то его приоритеты сдвигаются.** Из-за совпадений первого и второго курса по выбору двигать приоритеты не надо.
#
# - Blended-курсы не трогайте, по ним не надо распределять, на другие курсы они никак не влияют.
#
# - Заведомо известно, что в процессе распределения не возникнет ситуации, когда на одно место претендуют студенты с одинаковым перцентилем.
#
# - На выходе ожидается файл res_fall.csv с результатами распределения на осенние курсы по выбору. Файл должен быть следующего формата:
#
#     * Три колонки: ID, course1, course2
#
#     * Если студент не попал на курс, но должен был, то вместо названия курса в ячейке должна быть строка "???"
#
#     * Если студент должен выбрать только один курс, то в колонке course2 для него должна стоять строка "-"
#
#     * Если студент должен выбрать два курса по выбору, то порядок в колонках course1 и course2 не важен.
#
#     * hint: для сохранения воспользуйтесь df.to_csv('solution.csv', index=None)
#
#
# Для работы вам могут понадобиться следующие данные:
#
# - Результаты опроса (вы уже использовали этот файл в первой части задания, но на всякий случай ссылка: https://www.dropbox.com/s/f4rm8sjc3v99p0m/_end_seminar.xlsx?dl=0)
#
# - Соответствие номеров групп специализациям:
#
#     * 171, 172 - МОП; 173 - ТИ; 174 — АДИС; 175, 176 — РС; 177 — АПР
#
#     * У студентов 18-го года номера групп соответствуют номерам до распределения по специализациям. Это означает, что по номеру группы 18* нельзя однозначно определить специализацию студента. При этом в рамках распределения важно знать информацию только о двух из них: МОП и МИ. Эти знание можно получить из колонок 'is_ml_student
# ' и 'is_mi' соответственно.
#
# - Ограничения по количеству мест на курсах по выбору:
#
#     * Осенние: везде 30 мест, кроме Statistical Learning Theory (60 мест), Высокопроизводительных вычислений (60 мест), Анализа неструктурированных данных ($\infty$ мест)
#
#     * Весенние: везде 30 мест, кроме Обучения с подкреплением (60 мест), Анализа данных в бизнесе (60 мест).
#
#
# Кстати, убедитесь, что в данных больше нет пропусков и повторных записей.

# %% [markdown]
# #### 0. Проверка
#
# Для начала давайте убедимся, что вы успешно выполнили задания первой части и проверим ваши данные на наличие пропусков и повторов:

# %% [markdown]
# **Т.к. наша версия датафрейма без повторов сохранена в df_last, то мы будем использовать его вместо df.**

# %%
#ячейка для быстрого отката в начало
#df = df.fillna({column: '' if df[column].dtype == 'object' else 0 for column in df.columns})
#df_last = df.sort_values(by='timestamp').drop_duplicates(subset='id', keep='last').reset_index(drop=True)

# %%
assert df_last.shape[0] == 347, 'В таблице остались повторы или потеряны данные'

assert df_last.isna().sum().sum() == 0, 'В таблице остались пропуски'

# %% [markdown]
# Если вы не получили AssertionError, то можете продолжать.

# %% [markdown]
# #### 1. [1.5 балл] Создайте новый признак, обозначающий, сколько осенних курсов должен выбрать студент
#
# В этом вам может помочь информация о специализации и группе стундента.

# %%
df_last['available_fall_courses'] = 1
df_last.loc[df_last['17_group'].isin([171, 172, 173]), 'available_fall_courses'] = 2
df_last.loc[(df_last['18_group'] != 0) & (df_last['is_mi'] == 1), 'available_fall_courses'] = 2

# %% [markdown]
# Проверка:

# %%
col_name = 'available_fall_courses'     # insert your new column name as str

assert(df_last[df_last['id'] == '2662600c2c37e11e62f6ee0b88452f22'][col_name] == 2).all()
assert(df_last[df_last['id'] == 'd555d2805e1d93d4f023e57dc4c8f403'][col_name] == 2).all()
assert(df_last[df_last['id'] == '8fe79f84f36e3a5d2d6745621321302c'][col_name] == 1).all()
assert(df_last[df_last['id'] == 'e4caca755ee0bdd711e18fb8084958b5'][col_name] == 1).all()

# %% [markdown]
# #### 2. [2 балла] Распределите студентов в соответствии с первым приоритетом

# %%
import numpy as np

# Собираем все осенние курсы
all_fall_courses = pd.concat([df_last["fall_1"], df_last["fall_2"], df_last["fall_3"]]).dropna().unique()

# Определяем ограничения по местам
course_limit = {
    "Statistical Learning Theory": 60,
    "Высокопроизводительные вычисления": 60,
    "Анализ неструктурированных данных": np.inf
}
default_limit = 30

df_last_sorted = df_last.sort_values(by="percentile", ascending=True).reset_index(drop=True)

# Создаем словарь для учета записанных студентов
enrolled_students = {course: [] for course in all_fall_courses} #создаем пустой словарь, где ключи - это названия курсов, а значения - списки студентов, записанных на курс.
final_distribution = [] #cоздаем пустой список, в который будем записывать итоговое распределение студентов по курсам

# Проверяем, есть ли место на курсе
def course_restrictions(course):
    return pd.notna(course) and len(enrolled_students[course]) < course_limit.get(course, default_limit) and course not in assigned_courses

# Распределяем студентов
for i, student in df_last_sorted.iterrows():
    student_id = student['id']
    needed_courses = student['available_fall_courses']
    assigned_courses = ["???", "???"]  # заполняем "???" по умолчанию (так требовалось в условии)
    fall_courses = [student["fall_1"], student["fall_2"]]

    # Если студент может записаться только на 1 курс
    if needed_courses == 1:
        if course_restrictions(fall_courses[0]):
            assigned_courses[0] = fall_courses[0]
            enrolled_students[fall_courses[0]].append(student_id)
        else:
            assigned_courses[0] = "???"  # если в fall_1 нет мест, остается без курса
        assigned_courses[1] = "-"  # второй курс не нужен, fall_2 мы не рассматриваем

    # Если студент выбирает 2 курса
    elif needed_courses == 2:
        for i in range(2):  # Цикл на два курса
            for course in fall_courses:
                if course_restrictions(course):
                    assigned_courses[i] = course
                    enrolled_students[course].append(student_id)
                    break  # Записываем курс и выходим из внутреннего цикла

    final_distribution.append([student_id] + assigned_courses) #добавляем в итоговый список

# Создаем финальный дф в соответствии с требованиями в условии
df_result = pd.DataFrame(final_distribution, columns=["ID", "course1", "course2"])

df_result
# Out:
#                                    ID  \
# 0    3e106aaef8b24dbb01319c73e14c2936
# 1    3a7326c9e355a67d3805824ca34c4bc5
# 2    e0ca1a9548af9a3f98428c62420aa484
# 3    7fe7df0d207babbf30249b3063ac1f26
# 4    86d929f6fd741e56e93cee5900298849
# ..                                ...
# 342  79d14db48e4737af731960ae212d5134
# 343  40b18d40197e3db66312a026e06b8ff1
# 344  be4fa2120de3397ae21eac38ff0060e3
# 345  d539461bf254cf8b3201cdf7990b119e
# 346  7a21ef645ecb42198be493dd65320e78
#
#                                                course1  \
# 0                     Безопасность компьютерных систем
# 1                          Statistical Learning Theory
# 2                                 Матричные вычисления
# 3                    Высокопроизводительные вычисления
# 4      Сбор и обработка данных с помощью краудсорсинга
# ..                                                 ...
# 342  Принятие решений в условиях риска и неопределё...
# ...

# %%
all_fall_courses
# Out:
# array(['Безопасность компьютерных систем',
#        'Глубинное обучение в обработке звука',
#        'Высокопроизводительные вычисления', 'Statistical Learning Theory',
#        'Анализ неструктурированных данных',
#        'Байесовские методы машинного обучения', 'Язык SQL',
#        'Теория баз данных',
#        'Принятие решений в условиях риска и неопределённости',
#        'Сбор и обработка данных с помощью краудсорсинга',
#        'Матричные вычисления', 'Моделирование временных рядов'],
#       dtype=object)

# %%
# Проверим количество студентов на курсах
all_courses = pd.Series(df_result['course1'].tolist() + df_result['course2'].tolist()).value_counts().to_dict()
all_courses
# Out:
# {'-': 258,
#  '???': 108,
#  'Анализ неструктурированных данных': 48,
#  'Высокопроизводительные вычисления': 44,
#  'Statistical Learning Theory': 33,
#  'Безопасность компьютерных систем': 30,
#  'Сбор и обработка данных с помощью краудсорсинга': 30,
#  'Моделирование временных рядов': 30,
#  'Язык SQL': 29,
#  'Байесовские методы машинного обучения': 24,
#  'Глубинное обучение в обработке звука': 23,
#  'Матричные вычисления': 15,
#  'Теория баз данных': 14,
#  'Принятие решений в условиях риска и неопределённости': 8}

# %%
def get_first_match(df, search_course): #нам уже не нужно искать их перцентили, тк мы отсортировали наш датафрейм df_last по возрастанию перцентиля и в df_result они попадали в порядке возрастания
    match = df[(df["course1"] == search_course) | (df["course2"] == search_course)]
    if not match.empty:
        return match.iloc[0]  # возвращает первую совпавшую строку
    return None

def get_last_match(df, search_course):
    match = df[(df["course2"] == search_course) | (df["course1"] == search_course)]
    if not match.empty:
        return match.iloc[-1]  # возвращает последнюю совпавшую строку
    return None

for course in all_fall_courses:
    first_match = get_first_match(df_result, course)
    last_match = get_last_match(df_result, course)

    if first_match is not None:
        print(f"Первая запись для курса {course}: {first_match['ID']}")
    else:
        print(f"Для курса {course} первая запись не найдена")

    if last_match is not None:
        print(f"Последняя запись для курса {course}: {last_match['ID']}")
    else:
        print(f"Для курса {course} последняя запись не найдена")
# Out:
# Первая запись для курса Безопасность компьютерных систем: 3e106aaef8b24dbb01319c73e14c2936
# Последняя запись для курса Безопасность компьютерных систем: bf24738793f54467434ad78be13a42bf
# Первая запись для курса Глубинное обучение в обработке звука: 67e4ec4fe5c0601815692fbd6d403fb7
# Последняя запись для курса Глубинное обучение в обработке звука: d555d2805e1d93d4f023e57dc4c8f403
# Первая запись для курса Высокопроизводительные вычисления: 3a7326c9e355a67d3805824ca34c4bc5
# Последняя запись для курса Высокопроизводительные вычисления: b4f1f195bd1bc63490a7bc42275a71cd
# Первая запись для курса Statistical Learning Theory: 3a7326c9e355a67d3805824ca34c4bc5
# Последняя запись для курса Statistical Learning Theory: af20596134e83f3ca61259b325aa9688
# Первая запись для курса Анализ неструктурированных данных: 7f98e4487c7a910567f2d841e5e764c3
# Последняя запись для курса Анализ неструктурированных данных: d539461bf254cf8b3201cdf7990b119e
# ...

# %%
# Создаем столбцы с типом object, чтобы могли быть и True, и NaN
df_last['is_first_place'] = pd.Series([pd.NA] * len(df_last), dtype='boolean')
df_last['is_last_place'] = pd.Series([pd.NA] * len(df_last), dtype='boolean')

for course in all_fall_courses:
    first_match = get_first_match(df_result, course)
    last_match = get_last_match(df_result, course)

    if first_match is not None:
        df_last.loc[df_last['id'] == first_match['ID'], 'is_first_place'] = True

    if last_match is not None:
        df_last.loc[df_last['id'] == last_match['ID'], 'is_last_place'] = True

# %% [markdown]
# Здесь для проверки приведена таблица, в которой есть 2 дополнительные колонки:
#
#     1) is_first_place - является ли студент лучшим по перцентили хотя бы на одном из курсов, куда он был зачислен
#     (True / NaN)
#
#     2) is_last_place  - является ли студент худшим по перцентили хотя бы на одном из курсов, куда он был зачислен (True / NaN)

# %%
# !wget  -O '2_task_check.csv' -q 'https://www.dropbox.com/s/v8o2zzq3iz5gc9w/_2_task_check.csv?dl=0'
check_df = pd.read_csv('2_task_check.csv')

# %% [markdown]
# После распределения студентов в соответствии с первым приоритетом добавьте в свой датафрейм аналогичные признаки и запустите проверку:

# %%
fir_col_name = 'is_first_place'      # insert name of your new column with is_first_place as str
last_col_name = 'is_last_place'     # insert name of your new column with is_last_place as str


assert((df_last[df_last[fir_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
        ==
        check_df[check_df['is_first_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       ).id.values).all()


assert((df_last[df_last[last_col_name].isna() == False][['id']].sort_values('id').reset_index(drop=True)
       ==
       check_df[check_df['is_last_place'].isna() == False][['id']].sort_values('id').reset_index(drop=True)
      ).id.values).all()

# %% [markdown]
# #### 3. [3 балла] Проведите все три волны отбора студентов на курсы по выбору

# %% [markdown]
# По условию:
#
#
# *   для тех, кто может записаться на 1 курс, первая волна - это fall_1, вторая волна - fall_2, а третья волна - fall_3
# *   для тех, кому доступны 2 курса, fall_1+fall_2 - первая волна, fall_3 - вторая волна, а третьей волны нет

# %%
df_last_sorted = df_last.sort_values(by="percentile", ascending=True).reset_index(drop=True) #на всякий случай еще раз отсортируем

# Проведем вторую волну
for i, student in df_last_sorted.iterrows():
    student_id = student['id']
    fall_2_course = student['fall_2']
    fall_3_course = student['fall_3']
    needed_courses = student['available_fall_courses']

    # Соотносим id из df_last_sorted с ID из df_result
    assigned_courses = df_result.loc[df_result["ID"] == student_id, ["course1", "course2"]].values[0]

    # Если нужен 1 курс, но он не попал на fall_1, то нужно попробовать fall_2
    if needed_courses == 1 and assigned_courses[0] == "???":
        if course_restrictions(fall_2_course):
            assigned_courses[0] = fall_2_course
            enrolled_students[fall_2_course].append(student_id)

    # Если нужно 2 курса, пробуем fall_3 для незаполненных мест
    if needed_courses == 2:
        for i in range(2):
            if assigned_courses[i] == "???" and course_restrictions(fall_3_course):
                assigned_courses[i] = fall_3_course
                enrolled_students[fall_3_course].append(student_id)

    # Обновляем результаты
    df_result.loc[df_result["ID"] == student_id, ["course1", "course2"]] = assigned_courses

# Проверим результат
df_result
# Out:
#                                    ID  \
# 0    3e106aaef8b24dbb01319c73e14c2936
# 1    3a7326c9e355a67d3805824ca34c4bc5
# 2    e0ca1a9548af9a3f98428c62420aa484
# 3    7fe7df0d207babbf30249b3063ac1f26
# 4    86d929f6fd741e56e93cee5900298849
# ..                                ...
# 342  79d14db48e4737af731960ae212d5134
# 343  40b18d40197e3db66312a026e06b8ff1
# 344  be4fa2120de3397ae21eac38ff0060e3
# 345  d539461bf254cf8b3201cdf7990b119e
# 346  7a21ef645ecb42198be493dd65320e78
#
#                                                course1  \
# 0                     Безопасность компьютерных систем
# 1                          Statistical Learning Theory
# 2                                 Матричные вычисления
# 3                    Высокопроизводительные вычисления
# 4      Сбор и обработка данных с помощью краудсорсинга
# ..                                                 ...
# 342  Принятие решений в условиях риска и неопределё...
# ...

# %%
# Проверим количество студентов на курсах
all_courses = pd.Series(df_result['course1'].tolist() + df_result['course2'].tolist()).value_counts().to_dict()
all_courses
# Out:
# {'-': 258,
#  'Высокопроизводительные вычисления': 60,
#  '???': 56,
#  'Анализ неструктурированных данных': 53,
#  'Statistical Learning Theory': 41,
#  'Безопасность компьютерных систем': 30,
#  'Сбор и обработка данных с помощью краудсорсинга': 30,
#  'Глубинное обучение в обработке звука': 30,
#  'Моделирование временных рядов': 30,
#  'Язык SQL': 30,
#  'Байесовские методы машинного обучения': 25,
#  'Матричные вычисления': 24,
#  'Теория баз данных': 18,
#  'Принятие решений в условиях риска и неопределённости': 9}

# %%
# Проведем третью волну (только для тех, кому нужен 1 курс и они не попали в fall_1 и fall_2. Их нужно попробовать записать в fall_3)
for i, student in df_last_sorted.iterrows():
    student_id = student['id']
    fall_3_course = student['fall_3']
    needed_courses = student['available_fall_courses']

    # Соотносим id
    assigned_courses = df_result.loc[df_result["ID"] == student_id, ["course1", "course2"]].values[0]

    # Распределяем
    if needed_courses == 1 and assigned_courses[0] == "???":
        if course_restrictions(fall_3_course):
            assigned_courses[0] = fall_3_course
            enrolled_students[fall_3_course].append(student_id)

    # Обновляем дф
    df_result.loc[df_result["ID"] == student_id, ["course1", "course2"]] = assigned_courses

df_result
# Out:
#                                    ID  \
# 0    3e106aaef8b24dbb01319c73e14c2936
# 1    3a7326c9e355a67d3805824ca34c4bc5
# 2    e0ca1a9548af9a3f98428c62420aa484
# 3    7fe7df0d207babbf30249b3063ac1f26
# 4    86d929f6fd741e56e93cee5900298849
# ..                                ...
# 342  79d14db48e4737af731960ae212d5134
# 343  40b18d40197e3db66312a026e06b8ff1
# 344  be4fa2120de3397ae21eac38ff0060e3
# 345  d539461bf254cf8b3201cdf7990b119e
# 346  7a21ef645ecb42198be493dd65320e78
#
#                                                course1  \
# 0                     Безопасность компьютерных систем
# 1                          Statistical Learning Theory
# 2                                 Матричные вычисления
# 3                    Высокопроизводительные вычисления
# 4      Сбор и обработка данных с помощью краудсорсинга
# ..                                                 ...
# 342  Принятие решений в условиях риска и неопределё...
# ...

# %%
# Проверим количество студентов на курсах
all_courses = pd.Series(df_result['course1'].tolist() + df_result['course2'].tolist()).value_counts().to_dict()
all_courses
# Out:
# {'-': 258,
#  'Высокопроизводительные вычисления': 60,
#  'Анализ неструктурированных данных': 56,
#  'Statistical Learning Theory': 43,
#  '???': 38,
#  'Безопасность компьютерных систем': 30,
#  'Матричные вычисления': 30,
#  'Сбор и обработка данных с помощью краудсорсинга': 30,
#  'Глубинное обучение в обработке звука': 30,
#  'Моделирование временных рядов': 30,
#  'Язык SQL': 30,
#  'Байесовские методы машинного обучения': 25,
#  'Теория баз данных': 24,
#  'Принятие решений в условиях риска и неопределённости': 10}

# %%
df_result.to_csv('res_fall.csv', index = None)

# %% [markdown]
# На всякий случай просим вас сдать вместе с ноутбуком файл res_fall.csv к форме.

# %% [markdown]
# Вставьте картинку, описывающую ваш опыт выполнения этого задания:

# %% [markdown]
# ![image.png](data:image/png;base64,...)
